# %%
import numpy as np
import pandas as pd
import sklearn
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %%
students = pd.read_csv(r"C:\Users\Bhavya Chugh\Documents\kagglepython\New folder\data-science-for-good-careervillage\students.csv")
professionals = pd.read_csv(r"C:\Users\Bhavya Chugh\Documents\kagglepython\New folder\data-science-for-good-careervillage\professionals.csv")
matches = pd.read_csv(r"C:\Users\Bhavya Chugh\Documents\kagglepython\New folder\data-science-for-good-careervillage\answers.csv")
group_member = pd.read_csv(r"C:\Users\Bhavya Chugh\Documents\kagglepython\New folder\data-science-for-good-careervillage\group_memberships.csv")
emails = pd.read_csv(r"C:\Users\Bhavya Chugh\Documents\kagglepython\New folder\data-science-for-good-careervillage\emails.csv")
answers = pd.read_csv(r"C:\Users\Bhavya Chugh\Documents\kagglepython\New folder\data-science-for-good-careervillage\answers.csv")
questions = pd.read_csv(r"C:\Users\Bhavya Chugh\Documents\kagglepython\New folder\data-science-for-good-careervillage\questions.csv")

# %%
matches.head()
# Out:
#                          answers_id                 answers_author_id  \
# 0  4e5f01128cae4f6d8fd697cec5dca60c  36ff3b3666df400f956f8335cf53e09e
# 1  ada720538c014e9b8a6dceed09385ee3  2aa47af241bf42a4b874c453f0381bd4
# 2  eaa66ef919bc408ab5296237440e323f  cbd8f30613a849bf918aed5c010340be
# 3  1a6b3749d391486c9e371fbd1e605014  7e72a630c303442ba92ff00e8ea451df
# 4  5229c514000446d582050f89ebd4e184  17802d94699140b0a0d2995f30c034c6
#
#                 answers_question_id            answers_date_added  \
# 0  332a511f1569444485cf7a7a556a5e54  2016-04-29 19:40:14 UTC+0000
# 1  eb80205482e4424cad8f16bc25aa2d9c  2018-05-01 14:19:08 UTC+0000
# 2  eb80205482e4424cad8f16bc25aa2d9c  2018-05-02 02:41:02 UTC+0000
# 3  4ec31632938a40b98909416bdd0decff  2017-05-10 19:00:47 UTC+0000
# 4  2f6a9a99d9b24e5baa50d40d0ba50a75  2017-10-13 22:07:33 UTC+0000
#
#                                         answers_body
# 0  <p>Hi!</p>\n<p>You are asking a very interesti...
# ...

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
students['State'] = students['students_location'].str.split(',').str[1]
students['State'].value_counts()[:30].plot(kind='bar')
plt.show()

# %%
professionals['professionals_location'].value_counts()[:30].plot(kind='bar')
plt.show()

# %%
headline = df_prof['professionals_headline'].value_counts().head(10)
industry = professionals['professionals_industry'].value_counts().head(10)
plt_data = pd.DataFrame({'professionals_headline':headline,
                         'professionals_industry': industry})           
plt_data.plot(kind='bar', figsize=(15, 5))
plt.show()

# %%
import datetime as dt
plt_professionals = professionals.groupby([pd.to_datetime(professionals['professionals_date_joined']).dt.year]).size()
plt_students = students.groupby([pd.to_datetime(students['students_date_joined']).dt.year]).size()
plt_questions = questions.groupby([pd.to_datetime(questions['questions_date_added']).dt.year]).size()
plt_answers = answers.groupby([pd.to_datetime(answers['answers_date_added']).dt.year]).size()
# #plt_emails = (emails.groupby([emails['emails_date_sent'].dt.year]).size()/len(emails.index))
# #plt_comments = (comments.groupby([comments['comments_date_added'].dt.year]).size()/len(comments.index))
plt_data = pd.DataFrame({'students':plt_students,
                         'questions': plt_questions,
                         'professionals':plt_professionals,
                         'answers':plt_answers})
                        #'comments':plt_comments,
                        #'emails':plt_emails})
plt_data.plot(kind='bar', figsize=(15, 5))
plt.xlabel('Year')
plt.ylabel('Proportion')
plt.title('Distribution over time')
plt.show()
