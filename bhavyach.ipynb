# %%
import numpy as np
import pandas as pd

# %%
ca_data = pd.read_csv("covid19-local-us-ca-forecasting-week-1/ca_train.csv")

# %%
ca_data.tail(10)
# Out:
#     Id Province/State Country/Region      Lat      Long        Date  \
# 53  54     California             US  36.1162 -119.6816  2020-03-15
# 54  55     California             US  36.1162 -119.6816  2020-03-16
# 55  56     California             US  36.1162 -119.6816  2020-03-17
# 56  57     California             US  36.1162 -119.6816  2020-03-18
# 57  58     California             US  36.1162 -119.6816  2020-03-19
# 58  59     California             US  36.1162 -119.6816  2020-03-20
# 59  60     California             US  36.1162 -119.6816  2020-03-21
# 60  61     California             US  36.1162 -119.6816  2020-03-22
# 61  62     California             US  36.1162 -119.6816  2020-03-23
# 62  63     California             US  36.1162 -119.6816  2020-03-24
#
#     ConfirmedCases  Fatalities Month
# 53           426.0         6.0    15
# 54           557.0         7.0    16
# 55           698.0        12.0    17
# 56           751.0        13.0    18
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_axes([0,0,1,1])
#date = ca_data.Date[:][8:10]
date = ca_data.Date
ca_data['Month'] = ca_data['Date'].str[-2:]
cases = ca_data.ConfirmedCases
ax.bar(ca_data['Month'],cases)
plt.show()

# %%
from datetime import datetime
#date = datetime.strptime(ca_data.Date[:], '%Y-%m-$%d')
#date
#ca_data.Date[:][-1]
ca_data['Month'] = ca_data['Date'].str[-4:]
ca_data['Month']
# Out:
# 0     1-22
# 1     1-23
# 2     1-24
# 3     1-25
# 4     1-26
#       ...
# 58    3-20
# 59    3-21
# 60    3-22
# 61    3-23
# 62    3-24
# Name: Month, Length: 63, dtype: object
